# %%
import pandas as pd
import numpy as np
# import pandas_profiling
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/content/final.csv")
df.head()
# Out:
# <ipython-input-12-ac06abf324c4>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/final.csv")
#   Unnamed: 0  Year  FlightDate  DOT_ID_Reporting_Airline Tail_Number  \
# 0      19038  2024  2024-01-15                     20409      N945JT
# 1      19039  2024  2024-01-28                     19805      N990AU
# 2      19040  2024  2024-01-02                     19393      N7884G
# 3      19041  2024  2024-01-07                     20304      N311SY
# 4      19042  2024  2024-01-31                     20452      N642RW
#
#    Flight_Number_Reporting_Airline  OriginAirportID         OriginCityName  \
# 0                              616            14771      San Francisco, CA
# 1                              341            11298  Dallas/Fort Worth, TX
# 2                             3257            10821          Baltimore, MD
# 3                             3848            13487        Minneapolis, MN
# ...

# %%
# Filter for the year 2024
df = df[df['Year'] == 2024]

# Convert FlightDate to datetime format
df['FlightDate'] = pd.to_datetime(df['FlightDate'], format='%d-%m-%Y',errors='coerce')

# Extract the month from FlightDate
df['Month'] = df['FlightDate'].dt.month

# Group by month and calculate the average delay
monthly_delay = df.groupby('Month')['DepDelayMinutes'].mean().reset_index()

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Month', y='DepDelayMinutes', data=monthly_delay, palette='viridis')

# Customize the plot
plt.title('Average Departure Delay per Month in 2024')
plt.xlabel('Month')
plt.ylabel('Average Departure Delay (minutes)')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(axis='y')

# Show the plot
plt.show()

# %%
# # Count of flights by airline
# plt.figure(figsize=(12, 6))
# sns.countplot(data=df1, x='DOT_ID_Reporting_Airline')
# plt.title('Number of Flights by Airline')
# plt.xlabel('Airline ID')
# plt.ylabel('Number of Flights')
# plt.xticks(rotation=45)
# plt.show()

# %%
# # Count of flights by origin city
# plt.figure(figsize=(12, 6))
# origin_cities = df1['OriginCityName'].value_counts().head(10)
# sns.barplot(x=origin_cities.index, y=origin_cities.values)
# plt.title('Origin Cities')
# plt.xlabel('City')
# plt.ylabel('Number of Flights')
# plt.xticks(rotation=45)
# plt.show()

# %%
# # Convert 'FlightDate' from MM/DD/YYYY to datetime
# df1['FlightDate'] = pd.to_datetime(df1['FlightDate'], format='%m/%d/%Y', errors='coerce')

# %%
df_numeric = df.select_dtypes(include=['number'])
corr = df_numeric.corr()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Assuming your data is in a CSV file named 'your_data.csv'
#df1 = pd.read_csv('/content/final.csv') # Load your data into df1

# Average delays by airline
# avg_delay_by_airline = df1.groupby('DOT_ID_Reporting_Airline')['ArrDelayMinutes'].mean().sort_values()
# plt.figure(figsize=(12, 6))
# sns.barplot(x=avg_delay_by_airline.index, y=avg_delay_by_airline.values)
# plt.title('Average Arrival Delay by Airline')
# plt.xlabel('Airline ID')
# plt.ylabel('Average Arrival Delay (Minutes)')
# plt.xticks(rotation=45)
# plt.show()

# %%
# plt.figure(figsize=(12, 6))
# sns.boxplot(data=df[['ArrDelayMinutes', 'DepDelayMinutes']])
# plt.title('Box Plot of Arrival and Departure Delay Minutes')
# plt.ylabel('Delay Minutes')
# plt.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Assuming your data is in a CSV file named 'your_data.csv', and you've previously read it into df1:
# # If df1 contains the needed columns, use it directly
# df = df1

# # If you need to read the data again:
# # df = pd.read_csv('/content/final_preprocessed_data.csv')

# plt.figure(figsize=(12, 6))
# sns.boxplot(data=df[['ArrDelayMinutes', 'DepDelayMinutes']])
# plt.title('Box Plot of Arrival and Departure Delay Minutes')
# plt.ylabel('Delay Minutes')
# plt.show()

# %%
# plt.figure(figsize=(10, 6))
# sns.scatterplot(x='DepDelayMinutes', y='ArrDelayMinutes', data=df, alpha=0.6)
# plt.title('Scatter Plot of Arrival vs. Departure Delay Minutes')
# plt.xlabel('Departure Delay Minutes')
# plt.ylabel('Arrival Delay Minutes')
# plt.axhline(0, color='red', linestyle='--')
# plt.axvline(0, color='red', linestyle='--')
# plt.show()

# %%
# correlation_matrix = df[['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay', 'ArrDelayMinutes', 'DepDelayMinutes']].corr()
# plt.figure(figsize=(10, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# plt.title('Correlation Heatmap of Delay Reasons and Delay Minutes')
# plt.show()

# %%
# plt.figure(figsize=(12, 6))
# origin_cities = df1['OriginCityName'].value_counts().head(10).index
# filtered_df = df1[df1['OriginCityName'].isin(origin_cities)]
# sns.boxplot(data=filtered_df, x='OriginCityName', y='ArrDelayMinutes')
# plt.title('Arrival Delay Minutes by Origin City')
# plt.xticks(rotation=45)
# plt.show()

# %%
# df1 = pd.read_csv("final_merged_data.csv")

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
# # Histogram of Arrival Delay Distribution
# sns.histplot(df1['DepDelayMinutes'], bins=30)
# plt.xlim(0, 500)  # Set x-axis limit up to 500
# #plt.ylim(0, 300000)  # Set y-axis limit up to 175,000
# plt.title('Departure Delay Distribution')
# plt.show()

# %%
# plt.figure(figsize=(12, 6))
# sns.lineplot(data=df1, x='tavg', y='DepDelayMinutes')
# plt.title('Departure Delay vs Average Temperature')
# plt.xlabel('Average Temperature (°C)')
# plt.ylabel('Departure Delay (Minutes)')
# plt.show()

# %%
# plt.figure(figsize=(12, 6))
# sns.lineplot(data=df1, x='pres', y='DepDelayMinutes')
# plt.title('Departure Delay vs Pressure')
# plt.xlabel('Pressure (Hectopascals)')
# plt.ylabel('Departure Delay (Minutes)')
# plt.show()

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# df1 = pd.read_csv("final_merged_data.csv")

# # Verify if 'tavg' column exists, if not, use a different column or handle missing data
# if 'tavg' not in df1.columns:
#     print("Column 'tavg' not found in DataFrame. Available columns:")
#     print(df1.columns)
#     # Either replace 'alternative_column' with a valid column name or handle missing data
#     # For example, if 'avg_temp' is a valid alternative:
#     x_column = 'avg_temp'
# else:
#     x_column = 'tavg'

# plt.figure(figsize=(12, 6))
# sns.lineplot(data=df1, x=x_column, y='ArrDelayMinutes') # Changed 'tavg' to x_column
# plt.title('Arrival Delay vs Average Temperature')
# plt.show()

# %%
# plt.figure(figsize=(12, 6))
# sns.lineplot(data=df1, x='wspd', y='DepDelayMinutes')
# plt.title('Departure Delay vs Wind Speed')
# plt.xlabel('Wind Speed (Kilometres per hour)')
# plt.ylabel('Departure Delay (Minutes)')
# plt.show()

# %%
# plt.figure(figsize=(12, 6))
# sns.boxplot(x='DOT_ID_Reporting_Airline', y='ArrDelayMinutes', data=df1)
# plt.title('Arrival Delay by Airline')
# plt.xticks(rotation=45)
# plt.show()

# %%
# from sklearn.preprocessing import StandardScaler

# features = df1[['ArrDelayMinutes', 'CarrierDelay', 'Distance']]
# features = features.dropna()  # Ensure there are no NaN values
# scaler = StandardScaler()
# features_scaled = scaler.fit_transform(features)

# kmeans = KMeans(n_clusters=3)
# clusters = kmeans.fit_predict(features_scaled)
# df1['Cluster'] = clusters

# sns.scatterplot(x='ArrDelayMinutes', y='CarrierDelay', hue='Cluster', data=df1)
# plt.title('Clustering of Flights Based on Delays')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-166343c9ca63> in <cell line: 8>()
#       6 features_scaled = scaler.fit_transform(features)
#       7
# ----> 8 kmeans = KMeans(n_clusters=3)
#       9 clusters = kmeans.fit_predict(features_scaled)
#      10 df1['Cluster'] = clusters
#
# NameError: name 'KMeans' is not defined

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.cluster import KMeans # Import KMeans

# features = df1[['ArrDelayMinutes', 'CarrierDelay', 'Distance']]
# features = features.dropna()  # Ensure there are no NaN values
# scaler = StandardScaler()
# features_scaled = scaler.fit_transform(features)

# kmeans = KMeans(n_clusters=3)
# clusters = kmeans.fit_predict(features_scaled)
# df1['Cluster'] = clusters

# sns.scatterplot(x='ArrDelayMinutes', y='CarrierDelay', hue='Cluster', data=df1)
# plt.title('Clustering of Flights Based on Delays')
# plt.show()

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.cluster import KMeans

# features = df1[['ArrDelayMinutes', 'CarrierDelay', 'Distance']]

# # Instead of dropping NaNs, keep track of the original index:
# original_index = features.index

# Drop NaNs and reset index for features:
# features = features.dropna().reset_index(drop=True)

# scaler = StandardScaler()
# features_scaled = scaler.fit_transform(features)

# kmeans = KMeans(n_clusters=3)
# clusters = kmeans.fit_predict(features_scaled)

# # Create a new DataFrame with the clusters and original index:
# cluster_df = pd.DataFrame({'Cluster': clusters}, index=original_index)

# # Merge cluster_df back into df1 based on the index:
# df1 = df1.merge(cluster_df, left_index=True, right_index=True, how='left')

# sns.scatterplot(x='ArrDelayMinutes', y='CarrierDelay', hue='Cluster', data=df1)
# plt.title('Clustering of Flights Based on Delays')
# plt.show()

# %%
# features = df1[['ArrDelayMinutes', 'WeatherDelay', 'Distance']]
# features = features.dropna()  # Ensure there are no NaN values
# scaler = StandardScaler()
# features_scaled = scaler.fit_transform(features)

# kmeans = KMeans(n_clusters=3)
# clusters = kmeans.fit_predict(features_scaled)
# df['Cluster'] = clusters

# sns.scatterplot(x='ArrDelayMinutes', y='WeatherDelay', hue='Cluster', data=df)
# plt.title('Clustering of Flights Based on Delays')
# plt.show()

# %%
# sns.pairplot(df[['ArrDelayMinutes', 'tavg', 'prcp','snow','wspd']], diag_kind='kde')
# plt.show()

# %%
# correlation_matrix = df1[['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay', 'ArrDelayMinutes', 'DepDelayMinutes']].corr()
# plt.figure(figsize=(10, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# plt.title('Correlation Heatmap of Delay Reasons and Delay Minutes')
# plt.show()
